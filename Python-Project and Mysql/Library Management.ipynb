# %%
from tkinter import *
from PIL import Image, ImageTk

# %%
win=Tk()
win.state("zoomed")
win.configure(bg="#051554")
lbl_title=Label(win,text="Library Management", font=("Times new roman",50,"bold"),bg="#051554",fg="white")
lbl_title.pack()

# Logo 
img1=Image.open("E:\\Modules\\Project Session\\P\\Python\\library1.png")
img1=img1.resize((300,70))
imgtk1=ImageTk.PhotoImage(img1,master=win)
lbl_img1=Label(win,image=imgtk1)
lbl_img1.place(relx=0,rely=0)


# Make frame for Admin login
def admin_frame():
    frm=Frame(win)
    frm.configure(bg="#F5B041")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
    global imgtk,imgtk2,imgtk3
    # Down photo
    
    img=Image.open("E:\\Modules\\Project Session\\P\\Python\\down.jpeg")
    img=img.resize((1400,340))
    imgtk=ImageTk.PhotoImage(img,master=win)
    lbl_img=Label(frm,image=imgtk)
    lbl_img.place(relx=0,rely=.4)
    
    img2=Image.open("E:\\Modules\\Project Session\\P\\Python\\side1.webp")
    img2=img2.resize((368,260))
    imgtk2=ImageTk.PhotoImage(img2,master=win)
    lbl_img2=Label(frm,image=imgtk2)
    lbl_img2.place(relx=.71,rely=0)
    
    img3=Image.open("E:\\Modules\\Project Session\\P\\Python\\side2.jpg")
    img3=img3.resize((440,220))
    imgtk3=ImageTk.PhotoImage(img3,master=win)
    lbl_img3=Label(frm,image=imgtk3)
    lbl_img3.place(relx=0,rely=.06)

    # Title for Admin

    lbl_admin=Label(frm,text="Welcome Admin",fg="#2E4053",font=("Times new roman",25,"bold","underline"),bg="#F5B041")
    lbl_admin.place(relx=0, rely=0)

    # Label and Enter for the Admin

    lbl_user_name=Label(frm,text="User ID :",font=("times new roman",22,"bold"),bg="#F5B041",fg="Black")
    lbl_user_name.place(relx=.35,rely=.13)
    entry_user_name=Entry(frm,font=("times new roman",23,"bold"),bd=5)
    entry_user_name.place(relx=.45,rely=.13)

    # Label and Enter for the Admin & Password

    lbl_user_pswrd=Label(frm,text="Password:- ",font=("times new roman",22,"bold"),bg="#F5B041",fg="Black")
    lbl_user_pswrd.place(relx=.35,rely=.23)
    entry_user_pswrd=Entry(frm,font=("times new roman",23,"bold"),bd=5)
    entry_user_pswrd.place(relx=.45,rely=.23)
    
    # Login Function
    def login():
        frm.destroy()
        login_menu()
            

    # Login Button
    btn_login=Button(frm,command=login,text="Login",font=("times new roman",18,"bold"),bg="#85929E",fg="black",width=10)
    btn_login.place(relx=.46,rely=.33)

    # Reset Button
    btn_login=Button(frm,text="Reset",font=("times new roman",18,"bold"),bg="#85929E",fg="black",width=10)
    btn_login.place(relx=.58,rely=.33)

# login Menu Function
def login_menu ():
    frm=Frame(win)
    frm.configure(bg="#2C3E50")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
    # Function login
    def Login():
        frm.destroy()
        admin_frame() 
    
    # Logout Button
    btn_Logout=Button(frm,command=Login,text="Logout",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.9,rely=0)
       
    # Title for Admin 

    lbl_admin=Label(frm,text="Menu",font=("Times new roman",30,"bold","underline"),fg="white",bg="#2C3E50")
    lbl_admin.place(relx=0,rely=0)
    
    # Search Funtion
    def Search():
        frm.destroy()
        book_search()
    
    # Search Book Button
    btn_search_book=Button(frm,command=Search,text="Search",font=("times new roman",15,"bold"),bg="#909497",fg="white",bd=8,width=15)
    btn_search_book.place(relx=.45,rely=.20)
    
    def book_mgmt():
        frm.destroy()
        book_management()
        
    # Book Management Button
    btn_mgmt_book=Button(frm,command=book_mgmt,text="Book Management",font=("times new roman",15,"bold"),bg="#909497",fg="white",bd=8,width=15)
    btn_mgmt_book.place(relx=.45,rely=.3)
    
    # Allotment function
    def book_allot():
        frm.destroy()
        book_allotment()
        
    # Book Allotment Button
    btn_allt_book=Button(frm,command=book_allot,text="Book Allotment",font=("times new roman",15,"bold"),bg="#909497",fg="white",bd=8,width=15)
    btn_allt_book.place(relx=.45,rely=.40)
    
    #Refund Function
    
    def book_rfnd():
        frm.destroy()
        book_refund()
    
    # Refund Button
    btn_refund_book=Button(frm,command=book_refund,text="Book Refund",font=("times new roman",15,"bold"),bg="#909497",fg="white",bd=8,width=15)
    btn_refund_book.place(relx=.45,rely=.50)
    
# Book Management
def book_management():
    frm=Frame(win)
    frm.configure(bg="#515A5A")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
      # Function login
    def Login():
        frm.destroy()
        admin_frame() 
    
    # Logout Button
    btn_Logout=Button(frm,command=Login,text="Logout",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.9,rely=0)
    
    # Title For Book Management
    
    lbl_mgmt=Label(frm,text="Book Management",font=("Times new roman",25,"bold"),bg="#515A5A",fg="white")
    lbl_mgmt.place(relx=0,rely=0)
    
    # Function Back
    def Back():
        frm.destroy()
        login_menu()
    
    # Back Button
    btn_back=Button(frm,command=Back,text="Back",font=("Times New roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_back.place(relx=0,rely=.08)
    
    # Label and Entry for management book
    lbl_book_title=Label(frm,text="Title",font=("times new roman",25,"bold"),bg="#515A5A",fg="white")
    lbl_book_title.place(relx=.3,rely=.2)
    entry_book_title=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_title.place(relx=.4,rely=.2)
    entry_book_title.focus()
    
    # Label and Entry for book Author
    lbl_book_author=Label(frm,text="Author",font=("times new roman",25,"bold"),bg="#515A5A",fg="white")
    lbl_book_author.place(relx=.3,rely=.32)
    entry_book_author=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_author.place(relx=.4,rely=.32)
    
    # Label and Entry for book copies
    lbl_book_copy=Label(frm,text="Copies",font=("times new roman",25,"bold"),bg="#515A5A",fg="white")
    lbl_book_copy.place(relx=.3,rely=.44)
    entry_book_copy=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_copy.place(relx=.4,rely=.44)
    
    # Submit Button
    btn_Logout=Button(frm,text="Submit",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.5,rely=.54)

# Search Book Function

def book_search():
    frm=Frame(win)
    frm.configure(bg="#34495E")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
    # Function login
    def Login():
        frm.destroy()
        admin_frame() 
    
    # Logout Button
    btn_Logout=Button(frm,command=Login,text="Logout",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.9,rely=0)
    
    # Title For Book Management
    
    lbl_mgmt=Label(frm,text="Book Search",font=("Times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_mgmt.place(relx=0,rely=0)
    
    # Function Back
    def Back():
        frm.destroy()
        login_menu()
    
    # Back Button
    btn_back=Button(frm,command=Back,text="Back",font=("Times New roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_back.place(relx=0,rely=.08)
    
     # Label and Entry for Search book
    lbl_book_search_title=Label(frm,text="Title",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_book_search_title.place(relx=.3,rely=.2)
    entry_book_search_title=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_search_title.place(relx=.4,rely=.2)
    entry_book_search_title.focus()
    
    #Search Button
    btn_search=Button(frm,text="Search",font=("Times new roman",18,"bold"),bd=6,bg="#34495E",fg="white",width=6)
    btn_search.place(relx=.65,rely=.2)

# Book Allotment
def book_allotment():
    frm=Frame(win)
    frm.configure(bg="#34495E")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
     # Function Back
    def Back():
        frm.destroy()
        login_menu()
    
    # Back Button
    
    btn_back=Button(frm,command=Back,text="Back",font=("Times New roman",18,"bold"),bd=6,bg="#34495E",fg="white",width=7)
    btn_back.place(relx=0,rely=.08)
    
    #Title Book Allotment
    
    lbl_mgmt=Label(frm,text="Book Allotment",font=("Times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_mgmt.place(relx=0,rely=0)
      
    # Function login
    def Login():
        frm.destroy()
        admin_frame() 
    # Logout Button
    btn_Logout=Button(frm,command=Login,text="Logout",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.9,rely=0)
    
    # Label and Entry for management book
    lbl_book_title=Label(frm,text="Title",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_book_title.place(relx=.3,rely=.2)
    entry_book_title=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_title.place(relx=.47,rely=.2)
    entry_book_title.focus()
    
    # Label and Entry for book Author
    lbl_book_author=Label(frm,text="Author",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_book_author.place(relx=.3,rely=.32)
    entry_book_author=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_book_author.place(relx=.47,rely=.32)
    
    # Label and Entry for Student Name
    lbl_student_name=Label(frm,text="Student Name",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_student_name.place(relx=.3,rely=.44)
    entry_student_name=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_student_name.place(relx=.47,rely=.44)
    
     # Label and Entry for Student Roll No.
    lbl_student_roll=Label(frm,text="Student Roll",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_student_roll.place(relx=.3,rely=.56)
    entry_student_roll=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=17)
    entry_student_roll.place(relx=.47,rely=.56)
    # Submit Button
    btn_Logout=Button(frm,text="Allot",font=("Times new roman",18,"bold"),bd=6,bg="#34495E",fg="white",width=7)
    btn_Logout.place(relx=.58,rely=.66)
    
# Function for Book Refund

def book_refund():
    frm=Frame(win)
    frm.configure(bg="#34495E")
    frm.place(relx=0,rely=.12,relheight=1,relwidth=1)
    
    
    # Function Back
   
    def Back():
        frm.destroy()
        login_menu()
    
    # Back Button
    
    btn_back=Button(frm,command=Back,text="Back",font=("Times New roman",18,"bold"),bd=6,bg="#34495E",fg="white",width=7)
    btn_back.place(relx=0,rely=.08)
    
    #Title Book Allotment
    
    lbl_mgmt=Label(frm,text="Book Refund",font=("Times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_mgmt.place(relx=0,rely=0)
      
    # Function login
    def Login():
        frm.destroy()
        admin_frame() 
    # Logout Button
    btn_Logout=Button(frm,command=Login,text="Logout",font=("Times new roman",18,"bold"),bd=6,bg="#2C3E50",fg="white",width=7)
    btn_Logout.place(relx=.9,rely=0)
    
    # Label and Entry for Student Roll No.
    lbl_student_roll=Label(frm,text="Student Roll",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_student_roll.place(relx=.3,rely=.11)
    entry_student_roll=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=23)
    entry_student_roll.place(relx=.45,rely=.11)
    
    # Label for Alloted Book
 
    lbl_book_allot=Label(frm,text="Alloted Book:- ",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_book_allot.place(relx=.3,rely=.21)
    
     # Label and Entry for Student Roll No.
    lbl_student_roll=Label(frm,text="Return Book Id",font=("times new roman",25,"bold"),bg="#34495E",fg="white")
    lbl_student_roll.place(relx=.3,rely=.55)
    entry_student_roll=Entry(frm,font=("times new roman",23,"bold"),bd=5,width=21)
    entry_student_roll.place(relx=.48,rely=.55)
    


admin_frame()
win.mainloop()
